# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('p_rtt.csv',header=None)

# %%
df = df.values

# %%
X = df[:,0]
Y = df[:,1]

# %%
plt.xlabel('P')
plt.ylabel('Cumulitive RTT')
plt.title('P vs Cumulitive RTT')
plt.scatter(X,Y,marker = '*')
